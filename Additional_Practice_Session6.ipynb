# %% [markdown]
# #### Get Data from the following link: http://files.grouplens.org/datasets
# /movielens/ml-20m.zip
# #### We will be using the following files for this exercise:
# ratings.csv : userId,movieId,rating, timestamp
# tags.csv : userId,movieId, tag, timestamp
# movies.csv : movieId, title, genres

# %% [markdown]
# #### 1. Read the dataset using pandas.

# %%
import pandas as pd

# %%
dfrat=pd.read_csv("ratings.csv")

# %%
dfrat
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# ...

# %%
dftag=pd.read_csv("tags.csv")

# %%
dftag
# Out:
#         userId  movieId                                                tag  \
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %%
dfmovie=pd.read_csv('movies.csv')

# %%
dfmovie
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
#### 2. Extract the first row from tags and print its type.

# %%
dftag.iloc[0]
# Out:
# userId                18
# movieId             4141
# tag          Mark Waters
# timestamp     1240597180
# Name: 0, dtype: object

# %%
type(dftag.iloc[0] )
# Out:
# pandas.core.series.Series

# %%
#### 3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
dfrow = dftag.iloc[[0,11,2000]]
dfrow
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %%
#### 4. Print index, columns of the DataFrame.

# %%
 dftag.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
dfrat.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
dfmovie.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
#### 5. Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().

# %%
dfrat["rating"].mean()
# Out:
# 3.5255285642993797

# %%
dfrat["rating"].std()
# Out:
# 1.051988919275684

# %%
dfrat.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %%
#### 6. Filter out ratings with rating > 5

# %%
dfrat[dfrat["rating"]> 5]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
#### 7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
dfrat.isnull().count()
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %%
dfrat.replace('NaN','missing values').count()
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %%
dfmovie.isnull().count()
# Out:
# movieId    27278
# title      27278
# genres     27278
# dtype: int64

# %%
dfmovie.replace('NaN','missing values').count()
# Out:
# movieId    27278
# title      27278
# genres     27278
# dtype: int64

# %%
dftag.isnull().count()
# Out:
# userId       465564
# movieId      465564
# tag          465564
# timestamp    465564
# dtype: int64

# %%
dftag.replace('NaN','missing values').count()
# Out:
# userId       465564
# movieId      465564
# tag          465548
# timestamp    465564
# dtype: int64

# %%
#### 8. Filter out movies from the movies DataFrame that are of type 'Animation'.

# %%
dfmovie[dfmovie["genres"]=='Animation']
# Out:
#        movieId                                              title     genres
# 2503      2588                                   Cloudland (1998)  Animation
# 4906      5002                               Fritz the Cat (1972)  Animation
# 4907      5003            Nine Lives of Fritz the Cat, The (1974)  Animation
# 9455     27738                    Cathedral, The (Katedra) (2002)  Animation
# 9989     32840                                     Vincent (1982)  Animation
# 13444    66335                  Afro Samurai: Resurrection (2009)  Animation
# 13858    69469                        Garfield's Pet Force (2009)  Animation
# 14184    71158                Immigrants (L.A. Dolce Vita) (2008)  Animation
# 14492    72603                            Merry Madagascar (2009)  Animation
# 14578    72927                                 Donkey Xote (2007)  Animation
# 14580    72931                                       Tango (1981)  Animation
# ...

# %%
#### 9. Find the average rating of movies.

# %%
dfrat["rating"].mean()
# Out:
# 3.5255285642993797

# %%
dfrat.groupby('rating').mean()
# Out:
#               userId       movieId     timestamp
# rating
# 0.5     68273.393903  13356.246729  1.209060e+09
# 1.0     69266.000782   5652.208219  1.043247e+09
# 1.5     69305.992867  12377.773230  1.200202e+09
# 2.0     68996.772884   6733.595232  1.064063e+09
# 2.5     68643.592418  13669.268192  1.203932e+09
# 3.0     69074.100455   6770.763264  1.046027e+09
# 3.5     68841.218349  14814.098703  1.210879e+09
# 4.0     69138.370810   8342.514461  1.082045e+09
# 4.5     69053.127449  14585.414824  1.217216e+09
# 5.0     69111.904239   6275.356017  1.055206e+09

# %%
#### 10. Perform an inner join of movies and tags based on movieId.

# %%
dfmr = dfmovie.set_index('movieId').join(dfrat.set_index('movieId'),how='inner')

# %%
dfmr
# Out:
#                                                      title  \
# movieId
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# 1                                         Toy Story (1995)
# ...

# %%
#### 11. Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.

# %%
dfmr[(dfmr["genres"] == 'Comedy') & (dfmr["rating"] > 4)].iloc[:5]
# Out:
#                                       title  genres  userId  rating  \
# movieId
# 5        Father of the Bride Part II (1995)  Comedy     117     5.0
# 5        Father of the Bride Part II (1995)  Comedy     127     5.0
# 5        Father of the Bride Part II (1995)  Comedy     350     5.0
# 5        Father of the Bride Part II (1995)  Comedy     390     5.0
# 5        Father of the Bride Part II (1995)  Comedy     401     5.0
#
#           timestamp
# movieId
# 5         861553146
# 5         847127740
# 5        1360209812
# 5         836139583
# 5         847049988

# %%
#### 12. Split 'genres' into multiple columns.

# %%
#dfmoviegen =  dfmovie["genres"].apply(lambda x: x.split('|'))
dfmoviegen = dfmovie["genres"].str.split("|", n = 5, expand = True) 
dfmovie["genres1"] = dfmoviegen[0]
dfmovie["genres2"] = dfmoviegen[1]
dfmovie["genres3"] = dfmoviegen[2]
dfmovie["genres4"] = dfmoviegen[3]
dfmovie["genres5"] = dfmoviegen[4]
dfmovie.drop(columns =["genres"], inplace = True) 
dfmovie
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
#### 13. Extract year from title e.g. (1995).

# %%
import re
def get_year(name):
    return re.search('\s\((\d{4})\)$', name).groups()[0]
for name in dfmovie["title"]:
    print (get_year(name))
# Out:
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1994
# 1995
# 1994
# 1995
# 1995
# 1995
# 1995
# 1994
# 1995
# 1995
# 1996
# 1995
# 1996
# 1996
# 1996
# 1996
# 1995
# 1995
# 1995
# 1996
# 1995
# 1995
# 1995
# 1996
# 1996
# 1995
# 1995
# 1995
# 1996
# 1995
# 1995
# 1995
# 1995
# 1995
# 1995
# 1996
# 1996
# 1996
# 1995
# 1995
# 1996
# 1995
# 1996
# 1996
# 1995
# 1995
# 1994
# 1995
# 1996
# 1996
# 1996
# 1996
# 1996
# 1995
# 1994
# 1996
# 1996
# 1995
# 1995
# 1976
# 1995
# 1996
# 1995
# 1995
# 1995
# 1995
# 1996
# 1995
# 1996
# 1992
# 1992
# 1994
# 1995
# 1996
# 1994
# 1994
# 1994
# 1996
# 1995
# 1995
# 1995
# 1995
# 1995
# 1996
# 1995
# 1995
# 1995
# 1995
# 1996
# 1996
# 1988
# 1995
# ...

# %%
#### 14. Select rows based on timestamps later than 2015-02-01.

# %%
import datetime
def get_date(timestamp):
    datestr = datetime.datetime.fromtimestamp(timestamp)
    return datestr

# %%
dftag[(dftag["timestamp"].apply(lambda x: get_date(x)) > '2015-02-01')]
# Out:
#         userId  movieId                       tag   timestamp
# 301        318      260                     1970s  1424472169
# 302        318      260                   fantasy  1424472169
# 303        318      260                    sci-fi  1424472169
# 304        318   115149                    Action  1424534310
# 305        318   115149                   Revenge  1424534283
# 306        318   115149              Willem Dafoe  1424534383
# 324        342      318                masterplan  1423424898
# 326        342      318             prison escape  1423424898
# 327        342      318                redemption  1423424898
# 492        342    54372                    French  1422734628
# 493        342    54372            murder mystery  1422734632
# 494        342    54372              twist ending  1422734630
# 556        342    89118                disturbing  1422734236
# 557        342    89118              long revenge  1422734239
# ...

# %%
#### 15. Sort the tags DataFrame based on timestamp.

# %%
dftagsort=dftag.sort_values(by='timestamp')

# %%
dftagsort
# Out:
#         userId  movieId                              tag   timestamp
# 333932  100371     2788                     monty python  1135429210
# 333927  100371     1732                    coen brothers  1135429236
# 333924  100371     1206                  stanley kubrick  1135429248
# 333923  100371     1193                   jack nicholson  1135429371
# 333939  100371     5004                    peter sellers  1135429399
# 333922  100371       47                   morgan freeman  1135429412
# 333921  100371       47                        brad pitt  1135429412
# 333936  100371     4011                        brad pitt  1135429431
# 333937  100371     4011                      guy ritchie  1135429431
# 333920  100371       32                     bruce willis  1135429442
# 333933  100371     2858                     kevin spacey  1135429466
# 333931  100371     2329                     fuckoff nazi  1135429508
# 333930  100371     2329                    edward norton  1135429508
# ...
